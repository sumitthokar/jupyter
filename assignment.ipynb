# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Sumit </b>

# %% [markdown]
# *I have deep interest in data science because I love the part of data science where you solve the problem and give meaningful output from data.*

# %% [markdown]
# ### To check whether the input is even or not.

# %%
num=int(input("Enter a number:"))
if (num%2==0):
    print("Even.")
else:
    print("Odd.")
# Out:
# Enter a number:2
# Even.

# %% [markdown]
# - The
# - checking
# - of
# - the
# - number
# - is
# - done

# %% [markdown]
# 1. My
# 1. name
# 1. is
# 1. sumit

# %% [markdown]
# hello everyone
# ***
# I am sumit.
